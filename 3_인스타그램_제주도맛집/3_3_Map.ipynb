# %% [markdown]
# # 1. 데이터 준비하기

# %%
# 예제 3-20 크롤링 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('./files/3_1_crawling_raw.xlsx')
raw_total.head()
# Out:
#                                              content        date   like  \
# 0  더 늦기전에 제주도로 떠나쟈😍.#제주핫플레이스 간단히 1탄 모아봄!#제주여행 요 필...  2018-12-07  1,402
# 1  12월에 제주도를 가야하는이유🍊.#제주핫플 모음 끝판왕😍이거 하나면 겨울 #제주여행...  2018-12-03    368
# 2  11월 놓치지 말아야 할 제주 관광.가을바람이 최고조에 이르는 11월추운 겨울을 앞...  2018-11-02    166
# 3  국민학교세대#제주관광#제주살이#제주이주민#아라동주민#삼남매집 #새해첫날#드라이브#명...  2019-01-01     28
# 4  #제주관광 #제주 #돔나이트 #스트레스 #풀자 #춤추며 #땀날려 #가끔은괜찮아 #인...  2019-01-01     12
#
#     place                                               tags
# 0     NaN  ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 1     NaN  ['#제주핫플', '#제주여행', '#제주', '#제주도', '#제주도맛집', '#...
# 2     NaN  ['#honestin', '#어니스틴', '#제주여행', '#제주', '#제주도',...
# 3  명월국민학교  ['#제주관광', '#제주살이', '#제주이주민', '#아라동주민', '#삼남매집'...
# 4     NaN  ['#제주관광', '#제주', '#돔나이트', '#스트레스', '#풀자', '#춤추...

# %%
# 예제 3-21 위치정보 가져오기
location_counts = raw_total['place'].value_counts( )
location_counts
# Out:
# Jeju                                  271
# Jeju-do                               179
# Jungle Book by Alice                  108
# Seogwipo                               66
# 제주도 크리스마스 박물관                          59
# 할로비치                                   51
# 제주에인감귤밭                                48
# Jeju Island                            40
# 성산일출봉 城山日出峰  Seongsan Ilchulbong       36
# 폼포코식당_pompokokitchen                   30
# 1100고지                                 25
# Nimome                                 24
# 월정리해변                                  19
# 석부작박물관                                 18
# 제주도 애월읍                                18
# 고집돌우럭중문점                               18
# 카멜리아 힐                                 17
# 알뜨르 비행장                                17
# 제주 함덕 서우봉 해변                           16
# 밥깡패                                    16
# 제주레포츠랜드                                16
# 제주신화월드 Jeju Shinhwa World              15
# 제주고궁한복카페 jeju gogung hanbok studio     15
# 위미동백나무군락지                              15
# 제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地            15
# Woljeongri Beach                       14
# 연동 바오젠 거리                              14
# 협재해변 Beach                             14
# 김녕미로공원 Jeju Kimnyoung Maze Park        13
# 고래배꼽                                   12
#                                      ...
# 초콜릿랜드 / Chocolate Land                  1
# 도라지식당                                   1
# Nolman                                  1
# 코코몽 에코랜드                                1
# 김녕함바그집                                  1
# 델문도 제주 카페 Cafe Delmoondo                1
# 닭머르                                     1
# 서귀포의료원                                  1
# 접대 - 저번에 우리가 만났던 그때                     1
# 시루애월 소길점                                1
# 하림각                                     1
# Ocean Suite Jeju Hotel (오션스위츠제주호텔)      1
# 제주마라도잠수함                                1
# 연북정                                     1
# 서귀동 298-5 '세계의 가정식'                     1
# Jaju,south Korea                        1
# KBS본관                                   1
# 블루밍아일랜드 Blooming Island                 1
# 건축카페 - 섶섬이보이는                           1
# 호연스테이                                   1
# 올레 6코스 (Olle Route 6)                   1
# 반디앤로제이                                  1
# 엉또폭포                                    1
# 관덕정                                     1
# 정방폭포가 보이는 암벽위                           1
# 제주시도두항                                  1
# 노형 수목원가는길                               1
# 노형로터리                                   1
# 백리향백반                                   1
# Seoul, Korea                            1
# Name: place, Length: 1028, dtype: int64

# %%
# 예제 3-22 등록된 위치정보별 빈도수 데이터
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                       place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59

# %%
# 예제 3-23 위치정보 빈도수 데이터 저장하기
location_counts_df.to_excel('./files/3_3_location_counts.xlsx')

# %%
# 예제 3-24 위치정보 종류 확인하기
locations = list( location_counts.index )
locations
# Out:
# ['Jeju',
#  'Jeju-do',
#  'Jungle Book by Alice',
#  'Seogwipo',
#  '제주도 크리스마스 박물관',
#  '할로비치',
#  '제주에인감귤밭',
#  'Jeju Island',
#  '성산일출봉 城山日出峰  Seongsan Ilchulbong',
#  '폼포코식당_pompokokitchen',
#  '1100고지',
#  'Nimome',
#  '월정리해변',
#  '석부작박물관',
#  '제주도 애월읍',
#  '고집돌우럭중문점',
#  '카멜리아 힐',
#  '알뜨르 비행장',
#  '제주 함덕 서우봉 해변',
#  '밥깡패',
#  '제주레포츠랜드',
#  '제주신화월드 Jeju Shinhwa World',
#  '제주고궁한복카페 jeju gogung hanbok studio',
#  '위미동백나무군락지',
#  '제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地',
#  'Woljeongri Beach',
#  '연동 바오젠 거리',
#  '협재해변 Beach',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '고래배꼽',
#  '제주 성산 신산포구자연산횟집 회포장',
#  '새별오름',
#  '용머리해안',
#  '용눈이오름',
#  '하이엔드 제주',
#  '제주빅볼랜드',
#  '캔디원',
#  '사려니숲길',
#  '제주어린왕자게스트하우스',
#  '마마뜰',
#  '위미2리 동백군락지',
#  '한라산',
#  'Jeju Aewol',
#  'Jeju Island 제주특별자치도 济州道',
#  '옹포리',
#  '제주커피박물관 Baum',
#  '서귀포 느영나영 게스트하우스',
#  '삼무공원',
#  '휴애리 자연생활공원',
#  '위미동백나무군락',
#  '광치기해변',
#  '카페한라산',
#  '한라산 (漢拏山, Hallasan)',
#  '서우봉',
#  '제주해남',
#  '월정리카페콧수염',
#  '성이시돌목장',
#  '제주 송악산',
#  '옹포별장가든',
#  '산굼부리',
#  '아줄레주',
#  '에코랜드',
#  '牛岛 Udo Island 우도',
#  '카페브리프',
#  '제주 꿈꾸는고래 스쿠버&게스트하우스',
#  '곽지해수욕장',
#  '노라바',
#  '퍼시픽랜드 - Pacific Land JEJU',
#  '제주동문재래시장',
#  '번개과학체험관',
#  '소세지가게',
#  '하도핑크',
#  '로타리과자점',
#  '고집돌우럭-gozipfish',
#  '르토아베이스먼트',
#  'Hidden Cliff / 히든 클리프',
#  '우드노트',
#  '제주신라호텔',
#  '친봉산장',
#  '디저트쌀롱 톨',
#  'Terarosa - 테라로사',
#  '면차롱',
#  '비자림',
#  '제주 협재 해수욕장',
#  'Casa Linda Guesthouse-까사 린다 펜션',
#  '오전열한시',
#  '오후새우시',
#  '르페도라펜션',
#  'the cliff jeju - 더클리프 제주',
#  '오설록티뮤지엄',
#  '주상절리대',
#  '우아당',
#  '세화해수욕장',
#  'Jungmun Beach',
#  '제주도',
#  'LOTTE Hotel Jeju 롯데호텔제주',
#  '새별오름 (Saebyul Orum)',
#  '몽상드 애월 (Mônsant)',
#  'The Shilla Jeju',
#  'Hidden Cliff Hotel & Nature',
#  '제주꿈꾸는고래',
#  '해발1950m 한라산 백록담',
#  '아날로그감귤체험',
#  'Jeju International Airport',
#  '서귀포 매일올레시장',
#  'Paris, France',
#  '함덕반하다',
#  '함덕487',
#  '지금이순간카페',
#  '춘심이네 본점',
#  'Busan, South Korea',
#  '하늘아래 게스트하우스',
#  '수목원테마파크',
#  '탐라반상',
#  '명월국민학교',
#  '서귀포항',
#  '녹근로33',
#  '플레이스 캠프 제주',
#  '성산일출봉 게스트하우스 파티 띵까게스트하우스',
#  '커피캄머',
#  '만월당',
#  '남원큰엉해안경승지',
#  'Sunnyside Beachclub Jeju',
#  '쿠주',
#  '하례정원',
#  '법환동',
#  'Guzasien -구좌지앵',
#  '제주여행',
#  '애월늘',
#  '대평리',
#  '아름다운 제주도',
#  '선녀와나무꾼',
#  '인생밥집',
#  'Jeju horse Riding farm',
#  '안녕협재씨',
#  '환상의 섬 Jeju Island',
#  '앙뚜아네트',
#  '제주도 서귀포',
#  '천지연폭포 (Cheonjiyeon Waterfall)',
#  '혜화동버거',
#  '쇠소깍',
#  '제주 한라산 영실코스',
#  '제주국제공항',
#  '유동커피',
#  'Hamdeok Jeju',
#  '푸른섬 제주도',
#  '서귀포시 성산읍',
#  'Seoul, South Korea',
#  '제주 산굼부리',
#  '양가형제',
#  '금능해변',
#  '이익새양과점',
#  '붉은제주',
#  '보름우스테이',
#  '아뜰리에안',
#  '제주도 세화해변',
#  "블레블랑제리 Ble' Boulangerie",
#  '커피파인더coffeefinder제주시청',
#  '돈사돈',
#  '다람쥐식탁',
#  '안녕김녕sea',
#  '로얄',
#  '다랑쉬오름',
#  '한라수목원',
#  'Jejudo',
#  '제주도 월정리',
#  '설심당본점',
#  '스윗슬로cafe',
#  '제주 남원리',
#  'Harmduck Beach in Jeju Island',
#  '제주도 해안도로',
#  '명랑스낵',
#  '가시식당',
#  '영육일삼',
#  '로컬크랩',
#  '그초록',
#  '함덕호랑이',
#  '천제연폭포',
#  '애월더선셋',
#  '제주돌마을공원',
#  '제주도 천지연 폭포',
#  '복자씨연탄구이',
#  '난드르바당',
#  '황우지해안',
#  '서귀포흑돈',
#  '제주김만복',
#  '한림칼국수',
#  '애월해안가',
#  '형제국수',
#  '만세국수삼성혈점',
#  'Hotel Alfonso XIII, a Luxury Collection Hotel, Seville',
#  'Hamdoek Beach, Jeju Island',
#  '쿠오모제주',
#  '아쿠아 플라넷 제주 (Aqua Planet JEJU)',
#  '아도록',
#  'Cafe148',
#  '칠돈가',
#  '센트로',
#  'Meal Table Garden',
#  '카페두가시',
#  '그계절',
#  '우도',
#  '갈중이',
#  '탐나버거',
#  '용두암',
#  '볼스카페',
#  '아부오름',
#  '테디베어뮤지엄',
#  'Hyatt Regency, Jeju Island',
#  '제주서커스월드공연장',
#  '우동가게',
#  'Namwon Seogwipo Jeju,South korea',
#  '호텔 몽듀',
#  '선흘리 동백동산',
#  '평대우유차',
#  '순옥이네명가',
#  '부두식당',
#  '용연구름다리',
#  'Salon de Lavant',
#  '중문색달해변 (Jungmun Saekdal Beach)',
#  '모슬 포항',
#  '블리스찬',
#  '군산오름',
#  '천왕사 (天王寺)',
#  '백약이 오름',
#  '뉴저지카페',
#  'CAFE E.P.L',
#  '성산일출봉',
#  '빨간머리몽게스트하우스',
#  '외쿡식당',
#  'Daegu, South Korea',
#  '한림항',
#  '초밥충전',
#  '제스토리, 바이제주, 제주감성소품',
#  '제주 조류공원 화조원',
#  '올레7코스',
#  '남원읍 위미리 귤밭',
#  '붉은못허브팜 Cafe Redpond 애월본점',
#  '성산갯마을식당',
#  '컴피하우스',
#  'Ecoland Theme Park Forest Train黃花小火車',
#  '대정읍',
#  '빨간모자마법사',
#  'Antoinette',
#  '이정의댁',
#  '동굴카페 다희연(Cafe Daheeyeon in the Cave)',
#  '남원읍 신례리',
#  '토끼썸',
#  '한담해안산책로',
#  '비브레이브 커피 로스터즈',
#  '슬슬슬로우',
#  '가시아방',
#  '켄싱턴 제주호텔',
#  '한동올레펜션',
#  '이중섭 거리',
#  '훈이네고사리육개장',
#  'Longlive',
#  '김영갑갤러리 두모악',
#  '다다의작은공간',
#  'Osulloc Tea Museum',
#  '봄날',
#  '제주 서귀포 그릴 데미그라스',
#  '그러므로part.2',
#  '족황상제',
#  '서울맛집',
#  '신창풍차해안도로',
#  '済州島 - チェジュ島',
#  '보엠 - Bohème',
#  '사라봉근처',
#  '짱구분식',
#  '핏제리아마노',
#  '목장카페 드르쿰다',
#  'Ulsan, South Korea',
#  '평대리 해변',
#  '오롯',
#  '천지연폭포',
#  '제주도 한경면',
#  '토스카나호텔',
#  '상호네숯불구이',
#  '카페루핀',
#  '모뉴에트',
#  '소보리당로 222',
#  '카페주비 - JUBI',
#  '제주 휴애리',
#  '서귀포 까망돼지',
#  '대우정',
#  '판포리',
#  '제주 도두동',
#  '자매국수 노형점',
#  '테지움 제주',
#  '연정식당',
#  '어조횟집',
#  '제주도 전주횟집',
#  '이음',
#  'Oedolgae Jeju',
#  '제주시 아라동',
#  '해왓',
#  '앤트러사이트 제주 한림점',
#  '김녕회관',
#  '삼미흑돼지',
#  '문쏘',
#  '제주시 동문시장',
#  '제주시외버스터미널',
#  'Teddy Bear Museum - 제주 테디베어뮤지엄',
#  'JEJU앨리스',
#  '쌀다방',
#  '성읍민속마을',
#  '문치비',
#  '이런날엔',
#  '제주 구좌읍 세화리',
#  '테쉬폰',
#  '다미진횟집',
#  '새연교횟집',
#  '구좌읍 평대리',
#  '제주 윗세오름',
#  '박물관이살아있다',
#  '로맨틱무브',
#  '꽃기린 카페',
#  '광안리 해수욕장 - 廣安里海水浴場 GwangalliBeach, Busan, South Korea',
#  '윗세오름(해발 1700M)',
#  '지오반니',
#  '하도리1091',
#  '함덕해변',
#  'Hotel NANTA 호텔 난타',
#  '말젯문',
#  '이호테우해변',
#  '스튜디오 쿠나',
#  '제주 이호해수욕장',
#  '하얏트 리젠시 제주ㅣHyatt Regency Jeju',
#  '2월22일 브런치카페',
#  'Jeju_Gimnyeong_Maze_Park',
#  '제주허브동산',
#  '라온더마파크',
#  '따라비오름',
#  '중문 덤장',
#  '모슬포항 만선식당',
#  '제주마방목지',
#  '판포포구',
#  '신설오름',
#  '바닐라파레트',
#  '그리울땐 제주',
#  'South Korea',
#  '밥의정석',
#  'Vadada 바다다',
#  '제주시 새우리',
#  '빌리엔젤 제주노형점',
#  '제주 이호테우 해변',
#  '쭈니창고',
#  '한복입는 선흘집',
#  '나도섬이다',
#  '구좌상회',
#  '자연스러운식당',
#  '서촌제 (서울촌놈인제주)',
#  '네이처캔바스',
#  '8월의크리스마스 초원사진관',
#  '마모루',
#  'Halim jeju korea Selatan',
#  '털보네고양이',
#  'Bonte museum',
#  '올레길 5코스',
#  '금악리 제주힐링리조트',
#  'Thecoffeebrew-더커피브루',
#  '강정포구',
#  '타시텔레',
#  '하도해변',
#  '못생김',
#  '산방굴사 (Sanbanggulsa Temple 山房窟寺)',
#  'Arc de Triomphe',
#  '참맛나김밥',
#  '한라산버섯연구소',
#  '비자림 (Bija Forest, 榧子林)',
#  '구엄리 돌염전',
#  'Maxim 모카다방',
#  '헤밍웨이 하우스',
#  'Gimpo International Airport Station',
#  '카페송키',
#  '제주 오션스토리',
#  '필립헤어',
#  '선화동106-1',
#  '제주도 부영리조트',
#  'Cafe delmundo',
#  'Seosan',
#  '곱을락',
#  '카이로스 제주',
#  '인공위성 제주',
#  '제주시청',
#  '전라북도 군산 경암동 철길마을',
#  '말미오름 (두산봉)',
#  'Howard Johnson Jeju Yeondong Hotel - 하워드존슨 제주 연동 호텔',
#  '한모살식당',
#  '제주시동문시장',
#  '유채꽃사진촬영소',
#  '마구로쇼쿠도',
#  '해심가든',
#  '나주혁신도시',
#  "That's very",
#  'Kairos jeju',
#  '하노이안브라더스',
#  '우진해장국',
#  'Jeju Island, South Korea - 제주도',
#  '곽지스테이션',
#  '지금여기',
#  '동박낭',
#  '오는정 김밥',
#  '브라운스위트 제주',
#  '쿠쿠아림',
#  '썬앤문리조트',
#  '마포식당',
#  '자매국수 본점',
#  '성산수구레국밥',
#  '항파두리 항몽유적지',
#  '용두암해변',
#  '제주도 귤밭',
#  '지붕위제주바다',
#  '메이즈랜드',
#  '마로니에 공원',
#  '어부의딸',
#  '스타벅스 제주성산dt점',
#  '우도 비양도',
#  '고로케야',
#  '공천포 식당',
#  '제주프레임스파빌',
#  '모니카옛날통닭',
#  '함덕 Fishya',
#  '비긴어게인펜션',
#  '곰막 횟집',
#  '갈치왕',
#  '돌담너머바다',
#  '큰엉전망대쉼터',
#  '제주인에이에이',
#  'Málaga, Spain',
#  '카페록록 Loklok',
#  'Dammann Frères_다만프레르_제주신화점',
#  '민경이네 어등포해녀촌',
#  '웃뜨르 우리돼지',
#  '카페오드리',
#  '외도동',
#  '가드망제',
#  '아름다운제주여행',
#  '호박다방',
#  '스모크하우스인구억',
#  '비양도 해녀촌',
#  '큰돈가',
#  '중문 마린파크 퍼시픽랜드',
#  '광안리 앙상블',
#  '제주세계자연유산센터',
#  '제주베니스랜드',
#  'Jungle book by Alice',
#  '더스파',
#  '모메든식당',
#  '제주 성산읍',
#  '카페라능',
#  '제주도 하늘 위',
#  'Cafe Koomda',
#  '목수금토일',
#  '제주 팜스빌리지',
#  '아날로그감귤밭',
#  '고불락 식당',
#  '한라산 정상 해발 1,950m',
#  '바다사랑그리고추억',
#  '신흥동 일본식가옥',
#  "동광 pâtisserie '東光'",
#  '규태네 양곱창',
#  '국수바다',
#  '연화키친',
#  '동문시장',
#  '종달리 해변',
#  'Saeyeon Bridge, Jeju Island',
#  '산천단',
#  '군산 정상',
#  '관음사',
#  '돈사돈중문점',
#  '중문관광단지 (Jungmun Tourism Complex)',
#  '협재 수우동',
#  'Myeongjin Abalone',
#  'Cafe멘도롱',
#  '와흘리',
#  '무수천계곡',
#  '제주도 표선',
#  'Hibi & Kohaku',
#  '헤이브라더',
#  'Uncommon Table',
#  '섭지코지 등대',
#  '쉼표',
#  '촵촵 - Chwap Chwap',
#  '전주콩나물국밥',
#  '애월해안도로',
#  '날것',
#  '제주웰컴센터',
#  '쇠소깍오메기식당',
#  '월정곰닭',
#  '이게밥도둑',
#  '훈남횟집',
#  'Shimo-kitazawa Station',
#  '한림 바당길',
#  '게으른날',
#  '벵디',
#  'OLD STUFF 올드스터프 Coffee&bread',
#  '협제 혜변',
#  'CAMPHORTREE Hotel & Resort',
#  '국수의 전설',
#  '제주마로 펜션',
#  '남원 포구',
#  '마가리따 은혜씨cafe&Dining pub',
#  '에코그린리조트',
#  '제주칼국수 제주해물탕',
#  '새별오름 정상',
#  'TheFirst70 Hotel',
#  '올레길',
#  '책방무사',
#  '로드129',
#  '달달콤콤',
#  '렛츠런팜제주',
#  '월정스캔들',
#  '청초수물회&섭국 [신관]',
#  '정관신도시',
#  '동한두기',
#  '호텔 아이엠',
#  '홍키호테',
#  '깐깐한족발',
#  'Shmonga',
#  '단디501',
#  '제주함덕 해수욕장',
#  '몽구네민박',
#  '스트라이크볼링센터',
#  '제주카페 스르륵',
#  '토도',
#  '제주도 휘닉스아일랜드',
#  '네이처트레일',
#  '미도리',
#  '정동진',
#  'playce',
#  '노리매',
#  'Enough, 이너프',
#  '바다이야기',
#  '바라크라',
#  '성읍칠십리식당',
#  '니모메빈티지라운지',
#  '장복호',
#  '제주도 한림',
#  'Gimpo International Airport - 金浦国际机场 - 김포공항',
#  '팔도수산식당',
#  '현대백화점 울산점',
#  '서귀포 워터월드',
#  '제주국제공항 활주로 (Jeju Airport Runway)',
#  '고성리',
#  'Novotel Ambassador Daegu',
#  '표선 해비치해수욕장',
#  '카페어떤오후',
#  '카페닐스',
#  '한동리 화수목',
#  '제주 반디앤로제이 펜션 & 플라워브런치카페',
#  '대춘해장국',
#  '요요무문',
#  '릴리펏 제주점 메종글래드호텔',
#  '유리의성과마법의숲',
#  '모이세해장국',
#  '블랙하우스 떡볶이레스토랑',
#  '공업탑',
#  '종가전복',
#  'Ocean Suites Jeju Hotel',
#  '키작은삼촌',
#  '카페2472',
#  '배블리컨테이너',
#  '제주도맛집',
#  '김녕 성세기 해변',
#  '十五夜 siboya 십오야',
#  '저지예술인마을',
#  '사계여행',
#  '제주 이자와',
#  '제주도 올레길 6코스 이중섭거리',
#  '쉬림포크shrimpork',
#  '일도전복',
#  '제주워터월드/감귤노천탕',
#  '사는맛 먹는맛',
#  '명진전복',
#  'Tj Guesthouse',
#  '대우정식당',
#  '나원횟집',
#  '켄싱턴리조트 서귀포',
#  '머스태쉬커피/머스태쉬하우스',
#  'Bongcheon-dong',
#  '올레안뜰',
#  '성산스쿠버리조트',
#  '까망고띠',
#  '박물관은 살아있다 제주 중문',
#  '해녀엄마의집',
#  '해바라기 분식',
#  '정방 폭포',
#  '타쿠마 - Takuma',
#  '제주 생각하는 정원',
#  'Hallasan',
#  '자연뜨락',
#  '맛있는 제주',
#  '오라게게스트하우스',
#  '보목',
#  '거멍국수',
#  '카페하도섬/엠스테이펜션',
#  'Bronx, New York',
#  '삼다버거',
#  '교래 손 칼국수',
#  '더아트스테이호텔-The Artstay Hotel',
#  '오렌지블루스',
#  '행원포구',
#  '탕196',
#  '핸드테일러 제주점',
#  '폴레폴레게스트하우스 -Polepole Guesthouse in Jeju',
#  'Ulsan, Korea',
#  '동문로터리',
#  '흑돼지가있는풍경',
#  '유리네 식당',
#  'ECOLAND theme park',
#  '쉬리의 언덕',
#  '개똥이네 동물원',
#  '모닝딜라이트제주광양점',
#  '휘슬락호텔',
#  '서귀포잠수함',
#  '효돈마을',
#  '오설록',
#  '외돌개',
#  '서머셋 제주신화월드',
#  'LOTTE City Hotel Jeju 롯데시티호텔제주',
#  '풍미독서',
#  '북촌플레이스',
#  '에코랜드테마파크',
#  '1342틈',
#  '봉개동',
#  '절물 자연 휴양림',
#  '오조해녀의집',
#  '한림 뽈살집',
#  '스물다섯',
#  '청춘게스트하우스',
#  '어반가라지',
#  '제주한면가 濟州韓麵家',
#  '신천목장',
#  '제주신화월드 메리어트 리조트관',
#  '김녕 앞바다',
#  '제주도청',
#  '송당리 풍림다방',
#  '가시아방국수',
#  '마레벤또',
#  '포팩토리',
#  '문섬',
#  '라올레( La Olle)',
#  '블루마린하우스',
#  '시민갈비',
#  '강식당',
#  '쪼끌락 cafe',
#  '부촌식당',
#  '수제홍과일모찌하귀점',
#  '윈드스톤',
#  '칠돈가 본점',
#  '바램목장&카페',
#  '우도 하고수동해수욕장',
#  '뽕끄랑',
#  '모던플레이스 리조트',
#  '오샹띠',
#  '이호테우 목마등대',
#  '사우스바운더 Southbounder Brewery',
#  '양대곱',
#  'The Retrieve',
#  '성수족발',
#  '서귀포 이마트',
#  '채점석빵집',
#  '대굴대굴굴구이',
#  "Jerry's PUB",
#  '자구내포구',
#  '벵디1967',
#  '피규어뮤지엄제주',
#  '금바리',
#  '수월봉',
#  '소우',
#  '인사리',
#  '김녕해수욕장 (Gimnyeong Beach)',
#  '해비치호텔&리조트 - Haevichi hotel & resort',
#  '베케',
#  '삼보식당',
#  '제주초가집 곱들락',
#  '제주몬트락',
#  '서양차관',
#  '수카사',
#  '제주시 고요남',
#  '성산옥탑',
#  '제주 월령선인장 군락지',
#  '홍대부부',
#  '이중섭 미술관',
#  '동복해녀촌',
#  '경성대 맛집',
#  '빌라드아토',
#  '팀버 커피 제주',
#  '알동네국수',
#  '탑동마차',
#  '홍대 깐풍기브라더스',
#  '디스이즈핫',
#  '카페바띠',
#  '라비에 와인비스트로',
#  '시월의리브라',
#  '방주교회',
#  '덕수하루펜션',
#  '지붕 위 제주바다',
#  '푸릇프릍',
#  '잔향',
#  '물꼬기',
#  '바삭돈가스',
#  'Yacht Tour Shangri-La',
#  '자구리 카페 몬들락 Cafe Mondeulrak',
#  '카페 호꼼',
#  '제주송정농원',
#  'Saturdayisland',
#  'Volskafé',
#  '환상숲곶자왈공원',
#  '숨비아일랜드',
#  '바다의집',
#  '속초 엄지네포장마차',
#  '제주도 더마파크',
#  '광원',
#  '수망일기',
#  '몽키비치',
#  '협재',
#  '독개물항',
#  'Oslob, Cebu',
#  '사락',
#  '중문 단지 삼원정',
#  '은실이네 게스트하우스',
#  '카페오길',
#  '제주돈아',
#  'Marevo Resort / 마레보 리조트',
#  '미영이네식당',
#  '나인브릿지',
#  'BUTTON STAY 단추스테이 게스트하우스',
#  '제주도립미술관',
#  '사이카레',
#  '제주 대명리조트',
#  '스타양곱창',
#  '가배',
#  '충남 대천 해수욕장 에서',
#  '베이크샵스니프 bakeshop sniff',
#  '섶섬해녀할망카페',
#  '차귀도',
#  '한성식당',
#  '카페 하도섬',
#  'MBC',
#  '제주신라면세점',
#  '검은여식당',
#  '함덕 다래향',
#  '바람코지 게스트하우스&카페',
#  'Mansion37.5',
#  'Shilla Stay',
#  '종로 광장시장',
#  '부산 맛집 여기',
#  '서귀포 기억나는집',
#  '황궁쟁반짜장',
#  '꽃돼지연탄구이',
#  '돌마을공원',
#  '제주시 조천읍 와선로 206',
#  '모던하우스 제주점',
#  '오드랑베이커리',
#  '오마주마카롱',
#  '효섬마을 초가집',
#  '꽃밥',
#  '스테이 비갠오후',
#  '홍대개미제주',
#  '세영수산',
#  '오운커피',
#  '버드나무집',
#  '테디밸리골프리조트',
#  '객의하우스',
#  '색달식당',
#  '비싸이드엠,beside-M',
#  '神의 한모(신의 한모)',
#  '스테이굿무드',
#  '바굥식당',
#  '미풍해장국  중앙점',
#  '반딧불 한담',
#  '피규어 뮤지엄 제주  Figure Museum Jeju',
#  '구좌상회작업실',
#  '풍원 한라산볶음밥',
#  '돼지촌',
#  '돈물국수',
#  '아산 음봉',
#  '웃뜨르',
#  '고기마씸',
#  'La Tortuga',
#  'Jeju National University',
#  '우리집아점',
#  'Cafe카페인',
#  '성산포',
#  '한라생태숲',
#  '하늘고래',
#  '자갈자갈',
#  '용담해안도로',
#  '면뽑는선생 만두빚는아내',
#  '알뜨르프로젝트2018',
#  '투썸플레이스 제주애월한담점',
#  '형제섬',
#  '바보까페',
#  '세인트포cc',
#  '김포 구래동',
#  '사방팔방 외도점',
#  'Paju',
#  '신풍목장',
#  '수제홍과일모찌',
#  '돈테일러익스프레',
#  '안녕, 육지사람',
#  '리틀이태리 비스트로',
#  '제주인의밥상',
#  '미미본가',
#  '호텔위드제주',
#  '제주비치호텔 함덕',
#  '제주엠리조트',
#  '깡촌흑돼지',
#  '조천읍 북촌리',
#  '젠하이드어웨이',
#  '몽땅카페',
#  'Shineville Luxury Resort',
#  '고근산정상',
#  '카페모리&베이커스트리트',
#  '제주시 화북동',
#  '금능샌드',
#  '서촌제',
#  'Cafe Ri',
#  '맥도날드장안사거리점',
#  '석부작테마공원',
#  '제주돌문화공원',
#  '제주오리엔탈호텔',
#  '제주집',
#  '블루라군다이브-bluelagoondive',
#  'GD Cafe',
#  '하례리 망장포구',
#  '한화아쿠아넷',
#  '이어도전복해물전문점',
#  '서귀포흑돼지명가',
#  '제주시',
#  '남포커피',
#  '제주 운정이네',
#  '제주한라수목원♥',
#  'Jeju Starbucks 용담dt',
#  '제주조천스위스마을',
#  '우리두리게스트하우스',
#  '떡하니',
#  '달사막',
#  '키아스마',
#  '엉장매하우스',
#  '제주도가는 비행기 안',
#  '착한스시',
#  '꽃이다카페',
#  '제주 신재생에너지 홍보관',
#  '귀덕1리',
#  '연동포차',
#  '서귀포 칼호텔 (KAL Hotel Seogwipo)',
#  '산방산 (Sanbangsan)',
#  '전주도',
#  '제주아리아',
#  '에코랜드 라벤다앤그린티로즈가든역',
#  '제주 사랑분식',
#  '크랩잭제주',
#  '탑동해변공연장',
#  '낙지로',
#  '화북1동',
#  '여름문구사',
#  '흑송',
#  'Segovia, Spain',
#  'Cafe기억해',
#  '제주도 고근산',
#  '듀블라썸',
#  '한림공원 Hallimpark',
#  '도두항',
#  '대돈',
#  '포근한우리집',
#  'Maison GLAD Jeju - 메종글래드 제주',
#  '시루애월카페',
#  'Gwakji Beaches',
#  '헤이미쉬제주_제주독채펜션',
#  '괜찮은술책',
#  '제주거울미로 이상한나라의앨리스',
#  '덕인당 소락',
#  '제주마당',
#  '미나마라',
#  '마담제 게스트하우스',
#  '담아래',
#  '보롬왓',
#  '상효원 수목원',
#  'Salon De 소자38',
#  '제주김만복본점',
#  '동탄2에 산다',
#  '중문국수나라',
#  '고관해물탕, 초량',
#  '서건도',
#  'Ramada Plaza Jeju',
#  '호끌락80번지',
#  '청루 봉평 메밀 막국수',
#  'Cultured',
#  '청사포 수민이네',
#  '리치망고 협재점',
#  '다이브스테이',
#  'Villadeato-빌라드아토',
#  '73st',
#  '플레이스엉물',
#  '제주시농협하나로마트',
#  '삼공주회센터',
#  '제주하귀휴먼시아',
#  '제주롯데시네마',
#  '서귀포 법환포구',
#  '골목카페 옥수',
#  '제주아트리움"비밀의그림자"공연',
#  'Sensō-ji',
#  '소렉',
#  '도깨비명당',
#  '화순금모래해변',
#  '날씬흑돼지',
#  '내츄럴케이',
#  '에이그라운드',
#  '섭지코지 (Seopjikoji)',
#  '무거버거',
#  '제주도 하도리',
#  '돈사촌',
#  'Teseum',
#  '기쁨이네 감자탕',
#  '제주중문관광단지',
#  '과일애',
#  '랍스터빈_jeju',
#  '제주맑음',
#  '금능반지하',
#  '부자식당',
#  '쉐프부부',
#  '김녕장',
#  '성산일출봉 코앞 쉼터',
#  '스시애월',
#  '702키친',
#  '우도 (Udo / 牛島)',
#  '시리우스 호텔',
#  'Cafe가호',
#  '제주도 용두암',
#  '하이클래스 제주 (Hiclass Jeju)',
#  '유민 아르누보 콜렉션',
#  '기원뚝배기',
#  'Paz',
#  '도토리키친',
#  'U-do Bong( 우도봉)',
#  '저녁정원',
#  '한림 칠돈가',
#  '신창해안도로',
#  '표선리',
#  'Hwasun',
#  '순덕이네해산물장터',
#  'Gagamel',
#  '제주중앙로상점가',
#  '탑동광장편의점',
#  '어라운드 폴리 Around Follie',
#  '대기정',
#  '협재술시',
#  '평화통일불사리탑사',
#  '오메오메동문시장점',
#  '대구국제공항',
#  '속초 아바이마을',
#  '바당지기식당',
#  '내콩가',
#  'Jamae Guksu',
#  'M-STAY / 엠스테이',
#  '목포고을. 제주도 흑돼지 끝나는 맛!',
#  '동복해녀식당',
#  '제주 천제연폭포',
#  '비양도',
#  '제주여행 가야밀면',
#  '테라로사-이사랑',
#  '이스트엔드',
#  '옥계휴게소',
#  '1158 Cafe',
#  '덕승식당',
#  '비스트로낭',
#  '드렁큰디제이',
#  '소금바치 순이네',
#  '사라오름 산정호수',
#  '세종시',
#  '새우조나단',
#  '주점부리',
#  'Soror',
#  '협재칼국수',
#  '책다방',
#  '치저스 제주',
#  '여수 앞바다',
#  '산방산',
#  '제주 나인브릿지 CC',
#  '서귀포향토오일장',
#  '화산양꼬치2호점',
#  'Coco Mama',
#  '제주항공',
#  '해물뚝배기전문 재암식당',
#  '종달스토리 게스트하우스',
#  '제주좋은날',
#  'Sangumburi Crater',
#  '제주스럽닭',
#  '담앤루리조트',
#  '카페소금',
#  '제주대학교 교양강의동',
#  '원더먼트제주',
#  '더본호텔',
#  'Suweolbong Trekking',
#  '초콜릿랜드 / Chocolate Land',
#  '도라지식당',
#  ...]

# %%
# 예제 3-25 네이버지도 API 사용 예시
import requests

searching = '합정 스타벅스'
base_url = 'https://naveropenapi.apigw.ntruss.com/map-place/v1/search'
query_string = '?query={}&coordinate=126.977967,37.566329'.format(searching)
url = base_url + query_string

client_id = 'y86xoxxxxx'         
client_secret = 'cBxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'

headers = {'X-NCP-APIGW-API-KEY-ID': client_id, 
           'X-NCP-APIGW-API-KEY': client_secret} 

places = requests.get(url, headers = headers).json()['places']
places
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5494dc066f89> in <module>()
#      13            'X-NCP-APIGW-API-KEY': client_secret}
#      14
# ---> 15 places = requests.get(url, headers = headers).json()['places']
#      16 places
#
# KeyError: 'places'

# %%
# 예제 3-26 Search Place API 장소 검색 함수 만들기
def find_places(searching):
    # ① 접속URL 만들기
    base_url = 'https://naveropenapi.apigw.ntruss.com/map-place/v1/search'
    query_string = '?query={}&coordinate=126.977967,37.566329'.format(searching)
    url = base_url + query_string
    # ② headers 입력하기
    client_id = 'y86xoxxxxx'         
    client_secret = 'cB2gj68owMnDi45GgcoA2SomRV6gCxxxxxxxxxxx'
    headers = {'X-NCP-APIGW-API-KEY-ID': client_id, 
                   'X-NCP-APIGW-API-KEY': client_secret} 
    # ③ API 요청&정보 받기
    places = requests.get(url, headers = headers).json()['places']  
    # ④ 필요한 정보 선택하기
    place = places[0] 
    name = place['name']
    x=place['x']
    y=place['y']
    data = [name, x, y, searching] 

    return data

# %%
# 예제 3-27 제주공항 검색 예시
data = find_places('제주공항')
data

# %%
# 예제 3-28 인스타그램 위치명 위치정보 검색하기
import time

locations_inform = [ ]
for location in locations:
    try:
        data = find_places(location)       
        locations_inform.append(data) 
        time.sleep(0.5) 
    except:
        pass
locations_inform

# %%
# 예제 3-29 위치정보 저장하기
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['네이버위치명','경도','위도','인스타위치명']
locations_inform_df.to_excel('./files/3_3_locations.xlsx', index=False)

# %%
# 예제 3-30 인스타 게시량 및 위치정보 데이터 불러오기
location_counts_df = pd.read_excel('./files/3_3_location_counts.xlsx')
locations_inform_df = pd.read_excel('./files/3_3_locations.xlsx')

# %%
# 예제 3-31 위치 데이터 병합하기
location_data = pd.merge(locations_inform_df, location_counts_df, 
                         how = 'inner', left_on = 'name_official', right_index=True)
location_data.head()
# Out:
#    name_official           x          y     name  place
# 2           할로비치  126.281473  33.308420     할로비치     51
# 5         1100고지  126.462113  33.357935   1100고지     25
# 8        석부작테마공원  126.536553  33.250266   석부작박물관      1
# 11       제주레포츠랜드  126.637823  33.482415  제주레포츠랜드     16
# 12           밥깡패  126.263410  33.410117      밥깡패     16

# %%
# 예제 3-32 병합한 데이터 저장하기
location_data.to_excel('./files/3_3_location_inform.xlsx', index=False)

# %%
# 예제 3 33 데이터 불러오기
location_data = pd.read_excel('./files/3_3_location_inform.xlsx')
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 5 columns):
# name_official    433 non-null object
# x                433 non-null float64
# y                433 non-null float64
# name             433 non-null object
# place            433 non-null int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 17.0+ KB

# %%
location_data
# Out:
#     name_official           x          y               name  place
# 0            할로비치  126.281473  33.308420               할로비치     51
# 1          1100고지  126.462113  33.357935             1100고지     25
# 2         석부작테마공원  126.536553  33.250266             석부작박물관      1
# 3         제주레포츠랜드  126.637823  33.482415            제주레포츠랜드     16
# 4             밥깡패  126.263410  33.410117                밥깡패     16
# 5            고래배꼽  126.403453  33.480441               고래배꼽     12
# 6            새별오름  126.918614  37.553859               새별오름     12
# 7           용머리해안  126.314911  33.231502              용머리해안     11
# 8           용눈이오름  126.832684  33.459880              용눈이오름     11
# 9          제주빅볼랜드  126.375440  33.390259             제주빅볼랜드     10
# 10            캔디원  126.707734  33.471357                캔디원     10
# 11          사려니숲길  126.646289  33.401317              사려니숲길     10
# 12       위미동백나무군락  126.675975  33.273172           위미동백나무군락      9
# 13            마마뜰  126.333270  33.310068                마마뜰      9
# 14           삼무공원  126.491535  33.491727               삼무공원      9
# 15   제주커피박물관 Baum  126.899143  33.439798       제주커피박물관 Baum      9
# 16           제주해남  126.265938  33.435377               제주해남      8
# 17          광치기해변  126.924285  33.451625              광치기해변      8
# 18            서우봉  126.677586  33.545841                서우봉      8
# 19          카페한라산  126.862943  33.524834              카페한라산      8
# 20         성이시돌목장  126.327213  33.347074             성이시돌목장      7
# 21         옹포별장가든  126.257897  33.405006             옹포별장가든      7
# 22           아줄레주  126.839321  33.366831               아줄레주      6
# 23         곽지해수욕장  126.305403  33.451054             곽지해수욕장      6
# 24           산굼부리  126.694920  33.429576               산굼부리      6
# 25           산굼부리  126.694920  33.429576            제주 산굼부리      6
# 26           산굼부리  126.694920  33.429576  Sangumburi Crater      6
# 27          카페브리프  126.415672  33.458371              카페브리프      6
# 28           하도핑크  126.883434  33.522290               하도핑크      5
# 29           친봉산장  126.786412  33.471590               친봉산장      5
# ..            ...         ...        ...                ...    ...
# 403          몽키비치  126.411210  33.249508               몽키비치      1
# 404         꽃이다카페  127.916605  37.353783              꽃이다카페      1
# 405            소우  126.975057  37.571272                 소우      1
# 406           양대곱  126.531235  33.501300                양대곱      1
# 407          성산옥탑  126.934653  33.461545               성산옥탑      1
# 408     순덕이네해산물장터  126.896594  33.412248          순덕이네해산물장터      1
# 409         나도섬이다  126.665537  33.541950              나도섬이다      1
# 410          수망일기  126.712053  33.330351               수망일기      1
# 411        김녕함바그집  126.755355  33.556842             김녕함바그집      1
# 412        제주인의밥상  126.250450  33.218293             제주인의밥상      1
# 413            소렉  126.491251  33.488167                 소렉      1
# 414       에코그린리조트  126.291500  33.435303            에코그린리조트      1
# 415       자연스러운식당  126.532591  33.243426            자연스러운식당      1
# 416      환상숲곶자왈공원  126.263226  33.322829           환상숲곶자왈공원      1
# 417          73st  126.455052  33.456964               73st      1
# 418           산방산  126.313369  33.241563                산방산      1
# 419          올레안뜰  126.512910  33.237158               올레안뜰      1
# 420         알동네국수  126.620522  33.250894              알동네국수      1
# 421           비양도  126.967425  33.514733             우도 비양도      1
# 422           산천단  126.554085  33.447569                산천단      1
# 423          하늘고래  126.246106  33.399477               하늘고래      1
# 424         새우조나단  126.665179  33.542572              새우조나단      1
# 425         참맛나김밥  126.475196  33.478616              참맛나김밥      1
# 426           내콩가  126.393389  33.468243                내콩가      1
# 427          푸릇프릍  126.851183  35.146315               푸릇프릍      1
# 428        렛츠런팜제주  126.677513  33.415157             렛츠런팜제주      1
# 429           관음사  126.558466  33.423716                관음사      1
# 430            날것  126.526049  33.515358                 날것      1
# 431         날씬흑돼지  126.306532  33.238185              날씬흑돼지      1
# 432         깡촌흑돼지  126.667125  33.541306              깡촌흑돼지      1
#
# [433 rows x 5 columns]

# %%
# 예제 3 34 지도 표시하기
import folium

Mt_Hanla =[33.362500, 126.533694]
map_jeju = folium.Map(location = Mt_Hanla, zoom_start = 11)

for i in range(len(location_data)):
    name = location_data ['name_official'][i]    # 공식명칭
    count = location_data ['place'][i]           # 게시글 개수
    size = int(count)*2
    long = float(location_data['y'][i])      
    lat = float(location_data['x'][i])       
    folium.CircleMarker((long,lat), radius = size, color='red', popup=name).add_to(map_jeju)
    
map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 예제 3-35 지도 저장하기
map_jeju.save('./files/3_3_jeju.html')

# %%
# 예제 3-36 지도 표시하기(마커 집합)
from folium.plugins import MarkerCluster

locations = []
names = []

for i in range(len(location_data)):
    data = location_data.iloc[i]  # 행 하나씩
    locations.append((float(data['y']),float(data['x'])))    # 위도 , 경도 순으로..
    names.append(data['name'])




icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(30, 30)
    });
}"""

Mt_Hanla =[33.362500, 126.533694]
map_jeju2 = folium.Map(location = Mt_Hanla, zoom_start = 11)
                       
marker_cluster = MarkerCluster(
    locations=locations, popups=names,
    name='Jeju',
    overlay=True,
    control=True,
    icon_create_function=icon_create_function
)

marker_cluster.add_to(map_jeju2)
folium.LayerControl().add_to(map_jeju2)

map_jeju2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 예제 3-37 지도 저장하기
map_jeju2.save('./files/3_3_jeju_cluster.html')
